# %% [markdown]
# # Wildfire Database Project

# %%
import pandas as pd

# %%
# define filepath of raw csv files
economic_file = 'raw_data/economic_data/economic-damage-from-natural-disasters.csv'
number_file = 'raw_data/economic_data/number-of-natural-disaster-events.csv'
fema_file = 'raw_data/fema_data/database.csv'

# %% [markdown]
# ## Natural Disaster Economic Database

# %%
# import economic csv, isolate wildfire related data and drop 
# unnecessary columns
economic_df = pd.read_csv(economic_file)
economic_df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Total economic damage from natural disasters (US$)
# 0                                           30000000
# 1                                                  0
# 2                                                  0
# 3                                          480000000
# 4                                                  0

# %%
# locate wildfire in economic csv, rename bulky columns for postgres, 
# and drop unnecessary columns
economic_df = pd.read_csv(economic_file)
economic_df = economic_df.rename(columns = {'Total economic damage from natural disasters (US$)': 
                                            'total_wildfire_cost'})
economic_df = economic_df.loc[economic_df['Entity'] == 'Wildfire']
economic_df = economic_df.drop(columns = ['Code', 'Entity'])
economic_df.head()
# Out:
#      Year  total_wildfire_cost
# 517  1918            100000000
# 518  1922              8000000
# 519  1947             30000000
# 520  1965              1000000
# 521  1967             68500000

# %%
# economic_df.describe()

# %%
# import numbers csv, isolate wildfire related data and drop 
# unnecessary columns
number_df = pd.read_csv(number_file)
number_df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Number of reported natural disasters (reported disasters)
# 0                                                  5
# 1                                                  2
# 2                                                  9
# 3                                                  8
# 4                                                  2

# %%
# locate wildfire data, rename bulky columns for postgres, and drop unnecessary columns
number_df = number_df.rename(columns = {'Number of reported natural disasters (reported disasters)'
: 'total_wildfire'})
number_df = number_df.loc[number_df['Entity'] == 'Wildfire']
number_df = number_df.drop(columns = ['Code', 'Entity'])
number_df
# Out:
#      Year  total_wildfire
# 766  1911               1
# 767  1918               1
# 768  1922               1
# 769  1929               1
# 770  1939               1
# ..    ...             ...
# 823  2014               4
# 824  2015              12
# 825  2016              10
# 826  2017              13
# 827  2018              10
#
# [62 rows x 2 columns]

# %%
# merge number & yearly data into one dataframe with "Year" as a key
annual_data = pd.merge(economic_df, number_df, on='Year', how="outer")
# Sort "Year" to organize the data 
annual_data = annual_data.sort_values(["Year"])
# Reset the index number
final_annual_data = annual_data.reset_index(drop = True)
final_annual_data
# Out:
#     Year  total_wildfire_cost  total_wildfire
# 0   1911                  NaN               1
# 1   1918         1.000000e+08               1
# 2   1922         8.000000e+06               1
# 3   1929                  NaN               1
# 4   1939                  NaN               1
# ..   ...                  ...             ...
# 57  2014         2.590000e+08               4
# 58  2015         3.439820e+09              12
# 59  2016         6.287000e+09              10
# 60  2017         1.019000e+09              13
# 61  2018         2.274500e+10              10
#
# [62 rows x 3 columns]

# %% [markdown]
# ## FEMA Natural Disaster Dataset

# %%
fema_df = pd.read_csv(fema_file)
fema_df
# Out:
#       Declaration Number Declaration Type Declaration Date State  \
# 0                   DR-1         Disaster       05/02/1953    GA
# 1                   DR-2         Disaster       05/15/1953    TX
# 2                   DR-3         Disaster       05/29/1953    LA
# 3                   DR-4         Disaster       06/02/1953    MI
# 4                   DR-5         Disaster       06/06/1953    MT
# ...                  ...              ...              ...   ...
# 46180            DR-4301         Disaster       02/14/2017    CA
# 46181            DR-4301         Disaster       02/14/2017    CA
# 46182            DR-4301         Disaster       02/14/2017    CA
# 46183            DR-4301         Disaster       02/14/2017    CA
# 46184            DR-4301         Disaster       02/14/2017    CA
#
#                 County Disaster Type  \
# 0                  NaN       Tornado
# 1                  NaN       Tornado
# 2                  NaN         Flood
# 3                  NaN       Tornado
# 4                  NaN         Flood
# ...                ...           ...
# 46180    Sutter County         Storm
# 46181   Trinity County         Storm
# 46182  Tuolumne County         Storm
# 46183      Yolo County         Storm
# 46184      Yuba County         Storm
#
#                                       Disaster Title  Start Date    End Date  \
# 0                                            Tornado  05/02/1953  05/02/1953
# 1                         Tornado and Heavy Rainfall  05/15/1953  05/15/1953
# 2                                              Flood  05/29/1953  05/29/1953
# 3                                            Tornado  06/02/1953  06/02/1953
# 4                                             Floods  06/06/1953  06/06/1953
# ...                                              ...         ...         ...
# 46180  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46181  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46182  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46183  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
# 46184  Severe Winter Storms, Flooding, and Mudslides  01/03/2017  01/12/2017
#
#        Close Date Individual Assistance Program  \
# 0      06/01/1954                           Yes
# 1      01/01/1958                           Yes
# 2      02/01/1960                           Yes
# 3      02/01/1956                           Yes
# 4      12/01/1955                           Yes
# ...           ...                           ...
# 46180         NaN                            No
# 46181         NaN                            No
# 46182         NaN                            No
# 46183         NaN                            No
# 46184         NaN                            No
#
#       Individuals & Households Program Public Assistance Program  \
# 0                                   No                       Yes
# 1                                   No                       Yes
# 2                                   No                       Yes
# 3                                   No                       Yes
# 4                                   No                       Yes
# ...                                ...                       ...
# 46180                               No                       Yes
# 46181                               No                       Yes
# 46182                               No                       Yes
# 46183                               No                       Yes
# 46184                               No                       Yes
#
#       Hazard Mitigation Program
# 0                           Yes
# 1                           Yes
# 2                           Yes
# 3                           Yes
# 4                           Yes
# ...                         ...
# 46180                       Yes
# 46181                       Yes
# 46182                       Yes
# 46183                       Yes
# 46184                       Yes
#
# [46185 rows x 14 columns]

# %%
fema_df = pd.read_csv(fema_file)
# fema_df = fema_df.loc[fema_df['Declaration Type'] == 'Fire']
fema_df['Declaration Type'].unique()
# Out:
# array(['Disaster', 'Emergency', 'Fire'], dtype=object)

# %%
# import fema csv, isolate all fire-related data, then drop unnecessary columns
fema_df = pd.read_csv(fema_file)
fema_df = fema_df.loc[fema_df['Disaster Type'] == 'Fire']
fema_df["Disaster Title"].unique()
fema_df = fema_df.drop(columns = ['Declaration Number', 'Declaration Type', 
                                  'Disaster Type', 'Disaster Title', 
                                  'Individual Assistance Program', 
                                  'Individuals & Households Program', 
                                  'Public Assistance Program', 
                                  'Hazard Mitigation Program'])
# split year & add column to dataframe
date_split = fema_df['Declaration Date'].str.split('/', n=2, expand = True)
fema_df['Year'] = date_split[2]
# Change columns' name for Postgres
final_fema_df = fema_df.rename(columns = {"Declaration Date": "declaration_date", 
                                          "State": "state", "County": "county", 
                                          "Start Date": "start_date", 
                                          "End Date": "end_date", 
                                          "Close Date": "close_date", 
                                          "Year": "year"})
# Reset index number
final_fema_df = final_fema_df.reset_index(drop=True)
final_fema_df.head()
# Out:
#   declaration_date state          county  start_date    end_date  close_date  \
# 0       07/02/1953    NH             NaN  07/02/1953  07/02/1953  02/01/1956
# 1       12/29/1956    CA             NaN  12/29/1956  12/29/1956  04/01/1959
# 2       07/22/1960    ID             NaN  07/22/1960  07/22/1960  09/20/1961
# 3       11/16/1961    CA             NaN  11/16/1961  11/16/1961  08/01/1963
# 4       08/30/1967    ID  Benewah County  08/30/1967  08/30/1967  06/17/1970
#
#    year
# 0  1953
# 1  1956
# 2  1960
# 3  1961
# 4  1967

# %%
# export files to csv
final_fema_df.to_csv('clean_data/final_fema.csv')
final_annual_data.to_csv('clean_data/final_yearly_data.csv')
